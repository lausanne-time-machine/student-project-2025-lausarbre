# %%
import pandas as pd

# %%
excel_path = "../data/excel/1805.xlsx"

# %%
df = pd.read_excel(excel_path, header=0, index_col=0)

# %%
df
# Out:
#         nom_rue nom_rue_htr_corr nom_rue_norm no_maison proprietaire_nom  \
# 0     jn pierre        jn pierre  jean pierre         1         roguerol
# 1     jn pierre        jn pierre  jean pierre         ·                ·
# 2     jn pierre        jn pierre  jean pierre         ·                ·
# 3     jn pierre        jn pierre  jean pierre        21           comber
# 4     jn pierre        jn pierre  jean pierre         ·                ·
# ...         ...              ...          ...       ...              ...
# 3091     moulin           moulin       moulin         ·           martin
# 3092     moulin           moulin       moulin         ·                ·
# 3093  sanjalles        sanjalles    sanjalles         ·     a la commune
# 3094    challet          challet      challet         1                ·
# 3095     enfans           enfans       enfans         ·         secretan
#
#      proprietaire_nom_corr proprietaire_nom_htr_corr proprietaire_nom_norm  \
# ...

# %%
df.to_csv('../data/csv/1805.csv', index=False)

# %%
df = pd.read_csv("../data/csv/1805.csv")

# %%
df
# Out:
#         nom_rue nom_rue_htr_corr nom_rue_norm no_maison proprietaire_nom  \
# 0     jn pierre        jn pierre  jean pierre         1         roguerol
# 1     jn pierre        jn pierre  jean pierre         ·                ·
# 2     jn pierre        jn pierre  jean pierre         ·                ·
# 3     jn pierre        jn pierre  jean pierre        21           comber
# 4     jn pierre        jn pierre  jean pierre         ·                ·
# ...         ...              ...          ...       ...              ...
# 2971     moulin           moulin       moulin         ·           martin
# 2972     moulin           moulin       moulin         ·                ·
# 2973  sanjalles        sanjalles    sanjalles         ·     a la commune
# 2974    challet          challet      challet         1                ·
# 2975     enfans           enfans       enfans         ·         secretan
#
#      proprietaire_nom_corr proprietaire_nom_htr_corr proprietaire_nom_norm  \
# ...
